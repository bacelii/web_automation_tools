# %%
"""
Purpose: To collect all of the csvs from a natural gas website in the following:

Pseudocode: 
1) Collect time stamp
2) Go to starting website
3) Get the links to all the type of interstate, other midstream

"""
# Out:
# '\nPurpose: To collect all of the csvs from a natural gas website in the following:\n\nPseudocode: \n1) Collect time stamp\n2) Go to starting website\n3) Get the links to all the type of interstate, other midstream\n\n'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# c:\users\celii\appdata\local\programs\python\python37\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# # 1) Getting the links for all of the Gas Pipelines

# %%
verbose = True
categories = "Interstate"

# %%
query_deliminiter = "?"
base_url = "https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?code=ARLS"
category_class_name = "igdm_NautilusMenuItemHorizontalRootLink"


download_base = base_url[:base_url.find(query_deliminiter)]
page = requests.get(base_url)

# %%
soup = BeautifulSoup(page.content,"html.parser")

categories = soup.find_all(class_=category_class_name)
category_names = [k.span.text for k in categories]

link_dicts = []
for cat in categories:
    cat_name = cat.span.text
    
    a_links = cat.next_sibling.find_all("a")
    
    local_dicts = [dict(
        download_link = f'{download_base}?{a["href"][a["href"].find(query_deliminiter)+1:]}',
        name = a.span.text,
        category = cat_name) for a in a_links]
    
    if verbose:
        print(f"# of links in {cat_name} = {len(local_dicts)}")
    
    link_dicts += local_dicts
    
links_df = pd.DataFrame.from_records(link_dicts)
links_df
# Out:
# # of links in Interstate = 20
# # of links in Other = 2
# # of links in Midstream = 12
#                                         download_link  \
# 0   https://pipeline2.kindermorgan.com/LocationDat...
# 1   https://pipeline2.kindermorgan.com/LocationDat...
# 2   https://pipeline2.kindermorgan.com/LocationDat...
# 3   https://pipeline2.kindermorgan.com/LocationDat...
# 4   https://pipeline2.kindermorgan.com/LocationDat...
# 5   https://pipeline2.kindermorgan.com/LocationDat...
# 6   https://pipeline2.kindermorgan.com/LocationDat...
# 7   https://pipeline2.kindermorgan.com/LocationDat...
# 8   https://pipeline2.kindermorgan.com/LocationDat...
# 9   https://pipeline2.kindermorgan.com/LocationDat...
# 10  https://pipeline2.kindermorgan.com/LocationDat...
# 11  https://pipeline2.kindermorgan.com/LocationDat...
# 12  https://pipeline2.kindermorgan.com/LocationDat...
# 13  https://pipeline2.kindermorgan.com/LocationDat...
# 14  https://pipeline2.kindermorgan.com/LocationDat...
# 15  https://pipeline2.kindermorgan.com/LocationDat...
# 16  https://pipeline2.kindermorgan.com/LocationDat...
# 17  https://pipeline2.kindermorgan.com/LocationDat...
# 18  https://pipeline2.kindermorgan.com/LocationDat...
# 19  https://pipeline2.kindermorgan.com/LocationDat...
# 20  https://pipeline2.kindermorgan.com/LocationDat...
# 21  https://pipeline2.kindermorgan.com/LocationDat...
# 22  https://pipeline2.kindermorgan.com/LocationDat...
# 23  https://pipeline2.kindermorgan.com/LocationDat...
# 24  https://pipeline2.kindermorgan.com/LocationDat...
# 25  https://pipeline2.kindermorgan.com/LocationDat...
# 26  https://pipeline2.kindermorgan.com/LocationDat...
# 27  https://pipeline2.kindermorgan.com/LocationDat...
# 28  https://pipeline2.kindermorgan.com/LocationDat...
# 29  https://pipeline2.kindermorgan.com/LocationDat...
# 30  https://pipeline2.kindermorgan.com/LocationDat...
# 31  https://pipeline2.kindermorgan.com/LocationDat...
# 32  https://pipeline2.kindermorgan.com/LocationDat...
# 33  https://pipeline2.kindermorgan.com/LocationDat...
#
#                                name    category
# 0                 Arlington Storage  Interstate
# 1                   Cheyenne Plains  Interstate
# 2           Colorado Interstate Gas  Interstate
# 3                      Elba Express  Interstate
# 4               El Paso Natural Gas  Interstate
# 5                  Horizon Pipeline  Interstate
# 6              KM Illinois Pipeline  Interstate
# 7             KM Louisiana Pipeline  Interstate
# 8              Midcontinent Express  Interstate
# 9                   Mojave Pipeline  Interstate
# 10             Natural Gas Pipeline  Interstate
# 11                    Ruby Pipeline  Interstate
# 12            Sierrita Gas Pipeline  Interstate
# 13                     Southern LNG  Interstate
# 14             Southern Natural Gas  Interstate
# 15  Stagecoach Pipeline and Storage  Interstate
# 16           Tennessee Gas Pipeline  Interstate
# 17   TransColorado Gas Transmission  Interstate
# 18               Wyoming Interstate  Interstate
# 19                Young Gas Storage  Interstate
# 20             Keystone Gas Storage       Other
# 21               Twin Tier Pipeline       Other
# 22                     Banquete Hub   Midstream
# 23                      Camino Real   Midstream
# 24                 Copano Pipelines   Midstream
# 25        Kinderhawk Field Services   Midstream
# 26              KM Boarder Pipeline   Midstream
# 27             Eagle Ford Gathering   Midstream
# 28      Gulf Coast Express Pipeline   Midstream
# 29               KM Mexico Pipeline   Midstream
# 30          KM North Texas Pipeline   Midstream
# 31         Permian Highway Pipeline   Midstream
# 32                KM Tejas Pipeline   Midstream
# 33                KM Texas Pipeline   Midstream

# %%
links_df["download_link"].to_list()
# Out:
# ['https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=ARLS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=CPD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=CIGD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=EEC',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=EPGD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=HORZ',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMIL',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMLP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=MEP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=MOJD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=NGPL',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=RBYD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=SGP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=SLNG',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=SNGD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=STAG',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=TGPD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=TCP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=WICD',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=YGS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KGS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=TTP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=BANH',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=CRGS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=COP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KHFS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMBP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=EFGS',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=GCX',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMMX',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMNT',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=PHP',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMTJ',
#  'https://pipeline2.kindermorgan.com/LocationDataDownload/LocDataDwnld.aspx?TSP=KMTP']

# %% [markdown]
# # Go through and get the csv from one of the links

# %%
import selenium
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from pathlib import Path

import time


from os import sys
sys.path.append("../web_scrape_tools/")
import file_system_utils as fileu

# %%
driver_exe_path = "C:/Users/celii/Downloads/chromedriver_win32/chromedriver.exe"
retrieve_button_id = "WebSplitter1_tmpl1_ContentPlaceHolder1_HeaderBTN1_btnRetrieve"
download_button_id = "WebSplitter1_tmpl1_ContentPlaceHolder1_HeaderBTN1_btnDownload"

headless = False
append_source = True
ignore_empty_download = False

sleep_time_for_retrieve = 2
debug = False

# %%
if headless:
    options = Options()
    options.add_argument("--headless")
    assert options.headless
else:
    options = None

# %%
curr_path = str(Path(driver_exe_path).absolute())

if debug:
    print(f"Path to Chrome driver = {curr_path}")
    
driver = Chrome(curr_path,options = options)

# %%
"""
Purpose: Given a link where data can : 
1) Go to webpage
2) click the retrieve button
3) click the download button
4) wait for the download
5) Load the file as a dataframe and delete from downloads
"""
all_link_dfs = []
for data_dict in link_dicts:
    data_link = data_dict["download_link"]
    
    if verbose:
        print(f"\n-- Working on downloading {data_dict['category']}:{data_dict['name']} from \n {data_dict['download_link']}")
    
    driver.get(data_link)

    elem = driver.find_element(By.ID,retrieve_button_id)
    elem.click()

    time.sleep(sleep_time_for_retrieve)

    downloads = fileu.download_path()
    download_files = fileu.files_in_folder(downloads)

    if debug:
        print(f"# of download files before download = {len(download_files)}")

    elem = driver.find_element(By.ID,download_button_id)
    elem.click()

    fileu.download_wait(
        downloads,
        nfiles = len(download_files) + 1,
        verbose = False,
        verbose_while_waiting = False)

    if debug:
        print(f"# of download files after download = {len(download_files)}")

    download_files_after = fileu.files_in_folder(downloads)
    file = list(set(download_files_after).difference(download_files))[0]

    try:
        df = pd.read_csv(file)
    except:
        df = pd.read_excel(file)
        
    if not ignore_empty_download and len(df) == 0:
        raise Exception(f"The following data fetch had 0 entries: \n{data_dict}")

    if append_source:
        for k,v in data_dict.items():
            df[k] = v
        
    file.unlink()
    all_link_dfs.append(df)
    
all_link_dfs = pd.concat(all_link_dfs)
all_link_dfs

# %%
all_link_dfs["name"].unique().shape

# %%
# export to csv
export_filepath = "./download_data"

export_path = Path(export_filepath)
export_path = export_path.parent / Path(f"{export_path.stem}.csv")
all_link_dfs.to_csv(export_path)
