# %%
"""
8/20: Practice using beautifulsoup for doing web scrapping

Tutorial Website: 
https://realpython.com/beautiful-soup-web-scraper-python/

Fake Webpage: 
https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html

Notes: 
1) To inspect elements of wepage: CTr + Shift + I
"""

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip3 install requests
# !pip3 install beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\celii\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.1.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\celii\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from os import sys
sys.path.append("../web_scrape_tools/")

# %%
import request_utils as rqu

# %% [markdown]
# # 1) Practic Getting requests

# %%
rqu.print_status_code_cheat_sheet()
# Out:
# Informational responses (100–199)
# Successful responses (200–299)
# Redirection messages (300–399)
# Client error responses (400–499)
# Server error responses (500–599)

# %%
page = rqu.example_retrieve_html(verbose = True)
# Out:
# Status code = 200
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Fake Python</title>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bulma@0.9.2/css/bulma.min.css">
#   </head>
#   <body>
#   <section class="section">
#     <div class="container mb-5">
#       <h1 class="title is-1">
#         Fake Python
#       </h1>
#       <p class="subtitle is-3">
#         Fake Jobs for Your Web Scraping Journey
#       </p>
#     </div>
#     <div class="container">
#     <div id="ResultsContainer" class="columns is-multiline">
#     <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
# ...

# %% [markdown]
# # 2) Practice With Beautiful Soup

# %%
import beautiful_soup_utils as bsu

# %%
from bs4 import BeautifulSoup
import requests
url = "https://realpython.github.io/fake-jobs/"
page = requests.get(url)
#pass it page.content because if did page.text would have character encoding issus
soup = BeautifulSoup(page.content,"html.parser") 

results = soup.find(id="ResultsContainer")
print(results.prettify())
# Out:
# <div class="columns is-multiline" id="ResultsContainer">
#  <div class="column is-half">
#   <div class="card">
#    <div class="card-content">
#     <div class="media">
#      <div class="media-left">
#       <figure class="image is-48x48">
#        <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
#       </figure>
#      </div>
#      <div class="media-content">
#       <h2 class="title is-5">
#        Senior Python Developer
#       </h2>
#       <h3 class="subtitle is-6 company">
#        Payne, Roberts and Davis
#       </h3>
#      </div>
#     </div>
#     <div class="content">
#      <p class="location">
#       Stewartbury, AA
#      </p>
#      <p class="is-small has-text-grey">
#       <time datetime="2021-04-08">
#        2021-04-08
#       </time>
#      </p>
#     </div>
#     <footer class="card-footer">
# ...

# %%
bsu.example_find_element_by_id(page,id= "ResultsContainer")
# Out:
# <div class="columns is-multiline" id="ResultsContainer">
#  <div class="column is-half">
#   <div class="card">
#    <div class="card-content">
#     <div class="media">
#      <div class="media-left">
#       <figure class="image is-48x48">
#        <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
#       </figure>
#      </div>
#      <div class="media-content">
#       <h2 class="title is-5">
#        Senior Python Developer
#       </h2>
#       <h3 class="subtitle is-6 company">
#        Payne, Roberts and Davis
#       </h3>
#      </div>
#     </div>
#     <div class="content">
#      <p class="location">
#       Stewartbury, AA
#      </p>
#      <p class="is-small has-text-grey">
#       <time datetime="2021-04-08">
#        2021-04-08
#       </time>
#      </p>
#     </div>
#     <footer class="card-footer">
# ...

# %% [markdown]
# # 3) Finding Elements by Class Name

# %%
job_results = results.find_all("div",class_ = "card-content")

for idx,j in enumerate(job_results):
    print(f"--- Working on job {idx}---")
    title_element = j.find("h2",class_="title")
    company_element = j.find(f"h3",class_="company")
    location_element = j.find("p",class_="location")
    
    print(title_element)
    print(company_element)
    print(location_element)
# Out:
# --- Working on job 0---
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# <p class="location">
#         Stewartbury, AA
#       </p>
# --- Working on job 1---
# <h2 class="title is-5">Energy engineer</h2>
# <h3 class="subtitle is-6 company">Vasquez-Davidson</h3>
# <p class="location">
#         Christopherville, AA
#       </p>
# --- Working on job 2---
# <h2 class="title is-5">Legal executive</h2>
# <h3 class="subtitle is-6 company">Jackson, Chambers and Levy</h3>
# <p class="location">
#         Port Ericaburgh, AA
#       </p>
# --- Working on job 3---
# <h2 class="title is-5">Fitness centre manager</h2>
# <h3 class="subtitle is-6 company">Savage-Bradley</h3>
# <p class="location">
#         East Seanview, AP
#       </p>
# --- Working on job 4---
# <h2 class="title is-5">Product manager</h2>
# <h3 class="subtitle is-6 company">Ramirez Inc</h3>
# <p class="location">
#         North Jamieview, AP
# ...

# %%
bsu.example_find_all_elements_by_class()
# Out:
# --- Working on job 0---
# Senior Python Developer
# Payne, Roberts and Davis
# Stewartbury, AA
# --- Working on job 1---
# Energy engineer
# Vasquez-Davidson
# Christopherville, AA
# --- Working on job 2---
# Legal executive
# Jackson, Chambers and Levy
# Port Ericaburgh, AA
# --- Working on job 3---
# Fitness centre manager
# Savage-Bradley
# East Seanview, AP
# --- Working on job 4---
# Product manager
# Ramirez Inc
# North Jamieview, AP
# --- Working on job 5---
# Medical technical officer
# Rogers-Yates
# Davidville, AP
# --- Working on job 6---
# Physiological scientist
# Kramer-Klein
# South Christopher, AE
# --- Working on job 7---
# Textile designer
# Meyers-Johnson
# Port Jonathan, AE
# --- Working on job 8---
# Television floor manager
# Hughes-Williams
# Osbornetown, AE
# --- Working on job 9---
# Waste management officer
# Jones, Williams and Villa
# Scotttown, AP
# --- Working on job 10---
# Software Engineer (Python)
# Garcia PLC
# Ericberg, AE
# ...

# %% [markdown]
# # 4) More filtered searches

# %%
# returns nothing because is expecting an exact match
results.find_all("h2",string="Python")
# Out:
# []

# %% [markdown]
# ## can send in a function to return whether it should be matched or not

# %%
python_jobs = results.find_all("h2", string = lambda text: "python" in text.lower())
python_jobs
# Out:
# [<h2 class="title is-5">Senior Python Developer</h2>,
#  <h2 class="title is-5">Software Engineer (Python)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Software Developer (Python)</h2>,
#  <h2 class="title is-5">Python Developer</h2>,
#  <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>,
#  <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Software Developer (Python)</h2>]

# %%
bsu.example_find_all_with_filter_on_text()
# Out:
# []
# [<h2 class="title is-5">Senior Python Developer</h2>,
#  <h2 class="title is-5">Software Engineer (Python)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Software Developer (Python)</h2>,
#  <h2 class="title is-5">Python Developer</h2>,
#  <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>,
#  <h2 class="title is-5">Back-End Web Developer (Python, Django)</h2>,
#  <h2 class="title is-5">Python Programmer (Entry-Level)</h2>,
#  <h2 class="title is-5">Software Developer (Python)</h2>]

# %% [markdown]
# # Navigating the tree of the html

# %%
bsu.example_navigating_dom_tree()
# Out:
# []
# --- Working on job 0---
# Senior Python Developer
# Payne, Roberts and Davis
# Stewartbury, AA
# --- Working on job 1---
# Software Engineer (Python)
# Garcia PLC
# Ericberg, AE
# --- Working on job 2---
# Python Programmer (Entry-Level)
# Moss, Duncan and Allen
# Port Sara, AE
# --- Working on job 3---
# Python Programmer (Entry-Level)
# Cooper and Sons
# West Victor, AE
# --- Working on job 4---
# Software Developer (Python)
# Adams-Brewer
# Brockburgh, AE
# --- Working on job 5---
# Python Developer
# Rivera and Sons
# East Michaelfort, AA
# --- Working on job 6---
# Back-End Web Developer (Python, Django)
# Stewart-Alexander
# South Kimberly, AA
# --- Working on job 7---
# Back-End Web Developer (Python, Django)
# Jackson, Ali and Mckee
# New Elizabethside, AA
# --- Working on job 8---
# Python Programmer (Entry-Level)
# Mathews Inc
# Robertborough, AP
# --- Working on job 9---
# Software Developer (Python)
# Moreno-Rodriguez
# Martinezburgh, AE

# %% [markdown]
# # 6) Extracting attributes inside of the tags instead of just text

# %%
bsu.example_extracting_attribute_from_inside_tag()
# Out:
# ['https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/product-manager-4.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/textile-designer-7.html',
#  'https://www.realpython.com',
#  'https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8.html',
# ...
